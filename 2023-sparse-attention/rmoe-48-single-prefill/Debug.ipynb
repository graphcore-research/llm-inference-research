# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import json
sns.set_context("notebook")

# %%
def load_sweep(path: str) -> pd.DataFrame:
    with open(path) as f:
        return pd.DataFrame.from_dict(
            dict(**line, **result)
            for line in map(json.loads, f)
            if "results" in line
            for result in line["results"]
        ).drop(columns=["results"])

df = (pd.concat([load_sweep("data/sweep.jsonl").assign(run="one_prefill_causal_spV"),
                 load_sweep("data/sweep_original.jsonl").assign(run="two_prefill_causal_spV"),
                 load_sweep("data/sweep_original_v2.jsonl").assign(run="two_prefill"),
                 load_sweep("../rmoe-36-larger-models/data/sweep.jsonl").assign(run="two_prefill_original"),
                 ])
    .reset_index(drop=True)
    .pipe(lambda d: d.assign(score=np.where(d.match.isna(), d.rougeL, d.match.astype("float"))))
    .pipe(lambda d: d[d.model_scale == "1b"])
    .groupby(["run", "dataset", "sparsity", "k"], dropna=False).apply(lambda d: d.head(200 if d.dataset.iloc[0] == "cnn_dailymail" else 400))
    .reset_index(drop=True)
    .drop(columns="_duration")
)

# %%
(df
 .pipe(lambda d: d[d.dataset == "squad"])
 .pipe(lambda d: d[d.sparsity == "sparsev_after_avg"])
 .pipe(lambda d: d[d.k == 64])
 .pipe(lambda d: d[d.run.isin(["two_prefill", "two_prefill_original"])])
 .groupby("run").pipe(lambda d: d.head(10))
#  .groupby("run")[["match"]].mean()
 [["run", "id", "match", "output"]].style.hide()
 )
# Out:
# <style type="text/css">
# </style>
# <table id="T_e3728">
#   <thead>
#     <tr>
#       <th id="T_e3728_level0_col0" class="col_heading level0 col0" >run</th>
#       <th id="T_e3728_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_e3728_level0_col2" class="col_heading level0 col2" >match</th>
#       <th id="T_e3728_level0_col3" class="col_heading level0 col3" >output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e3728_row0_col0" class="data row0 col0" >two_prefill</td>
#       <td id="T_e3728_row0_col1" class="data row0 col1" >5711607f2419e314009555cf</td>
#       <td id="T_e3728_row0_col2" class="data row0 col2" >False</td>
#       <td id="T_e3728_row0_col3" class="data row0 col3" > coal, oil, natural gas, nuclear, hydroelectric, wind, solar, and biomass
# Question: What is the power</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row1_col0" class="data row1 col0" >two_prefill</td>
#       <td id="T_e3728_row1_col1" class="data row1 col1" >570d4329fed7b91900d45dd7</td>
#       <td id="T_e3728_row1_col2" class="data row1 col2" >True</td>
#       <td id="T_e3728_row1_col3" class="data row1 col3" > 1 July 1851
# Question: What was the name of the first governor of Victoria?
# Answer: Sir John Kerr
# </td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row2_col0" class="data row2 col0" >two_prefill</td>
#       <td id="T_e3728_row2_col1" class="data row2 col1" >572fdd03a23a5019007fcaa1</td>
#       <td id="T_e3728_row2_col2" class="data row2 col2" >False</td>
#       <td id="T_e3728_row2_col3" class="data row2 col3" > yes
# Question: MPs representing Welsh constituencies can only veto laws affecting which country?
# Answer: yes
# Question:</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row3_col0" class="data row3 col0" >two_prefill</td>
#       <td id="T_e3728_row3_col1" class="data row3 col1" >57274e145951b619008f87eb</td>
#       <td id="T_e3728_row3_col2" class="data row3 col2" >False</td>
#       <td id="T_e3728_row3_col3" class="data row3 col3" > Nepalese
# Question: What is the difference between a 'public school' and a 'private school'?
# Answer:</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row4_col0" class="data row4 col0" >two_prefill</td>
#       <td id="T_e3728_row4_col1" class="data row4 col1" >5733f309d058e614000b6649</td>
#       <td id="T_e3728_row4_col2" class="data row4 col2" >False</td>
#       <td id="T_e3728_row4_col3" class="data row4 col3" > The French killed about 200 men, and the British killed about 100.
# Question: What was the cause of the battle?</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row5_col0" class="data row5 col0" >two_prefill</td>
#       <td id="T_e3728_row5_col1" class="data row5 col1" >57338160d058e614000b5bfc</td>
#       <td id="T_e3728_row5_col2" class="data row5 col2" >True</td>
#       <td id="T_e3728_row5_col3" class="data row5 col3" > Committees
# Question: What is the role of the Mayor?
# Answer: The Mayor is the head of the Council.</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row6_col0" class="data row6 col0" >two_prefill</td>
#       <td id="T_e3728_row6_col1" class="data row6 col1" >5730c8a1f6cb411900e2449c</td>
#       <td id="T_e3728_row6_col2" class="data row6 col2" >True</td>
#       <td id="T_e3728_row6_col3" class="data row6 col3" > The Mission Council of the South Central Jurisdiction
# Question: What is the name of the decision that was made by the Mission</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row7_col0" class="data row7 col0" >two_prefill</td>
#       <td id="T_e3728_row7_col1" class="data row7 col1" >56f8c8469e9bad19000a04c7</td>
#       <td id="T_e3728_row7_col2" class="data row7 col2" >False</td>
#       <td id="T_e3728_row7_col3" class="data row7 col3" > He was warm and he was happy.
# Question: What did Luther do after the negotiations were done?
# Answer: He</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row8_col0" class="data row8 col0" >two_prefill</td>
#       <td id="T_e3728_row8_col1" class="data row8 col1" >56d728e00d65d2140019841c</td>
#       <td id="T_e3728_row8_col2" class="data row8 col2" >False</td>
#       <td id="T_e3728_row8_col3" class="data row8 col3" > Newton
# Question: Who was the first player to score a touchdown in Super Bowl 50?
# Answer: Newton
# Question:</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row9_col0" class="data row9 col0" >two_prefill</td>
#       <td id="T_e3728_row9_col1" class="data row9 col1" >57309564069b5314008321a9</td>
#       <td id="T_e3728_row9_col2" class="data row9 col2" >False</td>
#       <td id="T_e3728_row9_col3" class="data row9 col3" > The United States
# Question: Who was made poor and poor prior to World War 1
# Answer: The United States
# Question</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row10_col0" class="data row10 col0" >two_prefill_original</td>
#       <td id="T_e3728_row10_col1" class="data row10 col1" >5711607f2419e314009555cf</td>
#       <td id="T_e3728_row10_col2" class="data row10 col2" >False</td>
#       <td id="T_e3728_row10_col3" class="data row10 col3" > coal, oil, natural gas, nuclear, hydroelectric, wind, solar, and biomass.
# Question: What is the</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row11_col0" class="data row11 col0" >two_prefill_original</td>
#       <td id="T_e3728_row11_col1" class="data row11 col1" >570d4329fed7b91900d45dd7</td>
#       <td id="T_e3728_row11_col2" class="data row11 col2" >False</td>
#       <td id="T_e3728_row11_col3" class="data row11 col3" > 1st of August 1851
# Question: What was the name of the first governor of Victoria?
# Answer: Sir John</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row12_col0" class="data row12 col0" >two_prefill_original</td>
#       <td id="T_e3728_row12_col1" class="data row12 col1" >572fdd03a23a5019007fcaa1</td>
#       <td id="T_e3728_row12_col2" class="data row12 col2" >False</td>
#       <td id="T_e3728_row12_col3" class="data row12 col3" > yes
# Question: MPs representing Welsh constituencies can only veto laws affecting which country?
# Answer: yes
# Question:</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row13_col0" class="data row13 col0" >two_prefill_original</td>
#       <td id="T_e3728_row13_col1" class="data row13 col1" >57274e145951b619008f87eb</td>
#       <td id="T_e3728_row13_col2" class="data row13 col2" >False</td>
#       <td id="T_e3728_row13_col3" class="data row13 col3" > Nepalese
# Question: What is the difference between a 'public school' and a 'private school'?
# Answer:</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row14_col0" class="data row14 col0" >two_prefill_original</td>
#       <td id="T_e3728_row14_col1" class="data row14 col1" >5733f309d058e614000b6649</td>
#       <td id="T_e3728_row14_col2" class="data row14 col2" >False</td>
#       <td id="T_e3728_row14_col3" class="data row14 col3" > The French killed about 200 men, and the British killed about 100.
# Question: What was the cause of the battle?</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row15_col0" class="data row15 col0" >two_prefill_original</td>
#       <td id="T_e3728_row15_col1" class="data row15 col1" >57338160d058e614000b5bfc</td>
#       <td id="T_e3728_row15_col2" class="data row15 col2" >False</td>
#       <td id="T_e3728_row15_col3" class="data row15 col3" > 60
# Question: What is the difference between a majority and a two-thirds majority?
# Answer: A majority is a</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row16_col0" class="data row16 col0" >two_prefill_original</td>
#       <td id="T_e3728_row16_col1" class="data row16 col1" >5730c8a1f6cb411900e2449c</td>
#       <td id="T_e3728_row16_col2" class="data row16 col2" >True</td>
#       <td id="T_e3728_row16_col3" class="data row16 col3" > The Mission Council
# Question: Who is the president of the Mission Council?
# Answer: The Mission Council President
# Question:</td>
#     </tr>
#     <tr>
#       <td id="T_e3728_row17_col0" class="data row17 col0" >two_prefill_original</td>
#       <td id="T_e3728_row17_col1" class="data row17 col1" >56f8c8469e9bad19000a04c7</td>
#       <td id="T_e3728_row17_col2" class="data row17 col2" >False</td>
#       <td id="T_e3728_row17_col3" class="data row17 col3" > He was very happy and he was very excited

# %%
# Baselines are close enough; perhaps the minor differences are due to truncation?
(df
     .pipe(lambda d: d[d.sparsity == "none"])
     .groupby(["dataset", "run"])[["score"]].mean()
     .reset_index()
     .pivot(index=["dataset"], columns="run", values="score")
     [["two_prefill_original", "two_prefill", "two_prefill_causal_spV", "one_prefill_causal_spV"]]
     .style.format("{:.3f}")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0790e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >run</th>
#       <th id="T_0790e_level0_col0" class="col_heading level0 col0" >two_prefill_original</th>
#       <th id="T_0790e_level0_col1" class="col_heading level0 col1" >two_prefill</th>
#       <th id="T_0790e_level0_col2" class="col_heading level0 col2" >two_prefill_causal_spV</th>
#       <th id="T_0790e_level0_col3" class="col_heading level0 col3" >one_prefill_causal_spV</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0790e_level0_row0" class="row_heading level0 row0" >cnn_dailymail</th>
#       <td id="T_0790e_row0_col0" class="data row0 col0" >0.219</td>
#       <td id="T_0790e_row0_col1" class="data row0 col1" >0.220</td>
#       <td id="T_0790e_row0_col2" class="data row0 col2" >0.220</td>
#       <td id="T_0790e_row0_col3" class="data row0 col3" >0.220</td>
#     </tr>
#     <tr>
#       <th id="T_0790e_level0_row1" class="row_heading level0 row1" >squad</th>
#       <td id="T_0790e_row1_col0" class="data row1 col0" >0.375</td>
#       <td id="T_0790e_row1_col1" class="data row1 col1" >0.375</td>
#       <td id="T_0790e_row1_col2" class="data row1 col2" >0.375</td>
#       <td id="T_0790e_row1_col3" class="data row1 col3" >0.375</td>
#     </tr>
#     <tr>
#       <th id="T_0790e_level0_row2" class="row_heading level0 row2" >triviaqa</th>
#       <td id="T_0790e_row2_col0" class="data row2 col0" >0.323</td>
#       <td id="T_0790e_row2_col1" class="data row2 col1" >0.323</td>
#       <td id="T_0790e_row2_col2" class="data row2 col2" >0.323</td>
#       <td id="T_0790e_row2_col3" class="data row2 col3" >0.320</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Sparse-V is weird!
(df
     .pipe(lambda d: d[d.sparsity != "eviction"])
     .pipe(lambda d: d[d.k.isna() | (d.k == 64)])
     .groupby(["dataset", "run", "sparsity"])[["score"]].mean()
     .reset_index()
     .pivot(index=["dataset", "sparsity"], columns="run", values="score")
     [["two_prefill_original", "two_prefill", "two_prefill_causal_spV", "one_prefill_causal_spV"]]
     .style.format("{:.3f}")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9e5f9">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >run</th>
#       <th id="T_9e5f9_level0_col0" class="col_heading level0 col0" >two_prefill_original</th>
#       <th id="T_9e5f9_level0_col1" class="col_heading level0 col1" >two_prefill</th>
#       <th id="T_9e5f9_level0_col2" class="col_heading level0 col2" >two_prefill_causal_spV</th>
#       <th id="T_9e5f9_level0_col3" class="col_heading level0 col3" >one_prefill_causal_spV</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="index_name level1" >sparsity</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e5f9_level0_row0" class="row_heading level0 row0" rowspan="4">cnn_dailymail</th>
#       <th id="T_9e5f9_level1_row0" class="row_heading level1 row0" >none</th>
#       <td id="T_9e5f9_row0_col0" class="data row0 col0" >0.219</td>
#       <td id="T_9e5f9_row0_col1" class="data row0 col1" >0.220</td>
#       <td id="T_9e5f9_row0_col2" class="data row0 col2" >0.220</td>
#       <td id="T_9e5f9_row0_col3" class="data row0 col3" >0.220</td>
#     </tr>
#     <tr>
#       <th id="T_9e5f9_level1_row1" class="row_heading level1 row1" >sparsev_after</th>
#       <td id="T_9e5f9_row1_col0" class="data row1 col0" >0.210</td>
#       <td id="T_9e5f9_row1_col1" class="data row1 col1" >0.210</td>
#       <td id="T_9e5f9_row1_col2" class="data row1 col2" >0.218</td>
#       <td id="T_9e5f9_row1_col3" class="data row1 col3" >0.219</td>
#     </tr>
#     <tr>
#       <th id="T_9e5f9_level1_row2" class="row_heading level1 row2" >sparsev_after_avg</th>
#       <td id="T_9e5f9_row2_col0" class="data row2 col0" >0.197</td>
#       <td id="T_9e5f9_row2_col1" class="data row2 col1" >0.216</td>
#       <td id="T_9e5f9_row2_col2" class="data row2 col2" >0.201</td>
#       <td id="T_9e5f9_row2_col3" class="data row2 col3" >0.201</td>
#     </tr>
#     <tr>
#       <th id="T_9e5f9_level1_row3" class="row_heading level1 row3" >sparsev_before</th>
#       <td id="T_9e5f9_row3_col0" class="data row3 col0" >0.214</td>
#       <td id="T_9e5f9_row3_col1" class="data row3 col1" >0.214</td>
#       <td id="T_9e5f9_row3_col2" class="data row3 col2" >0.208</td>
#       <td id="T_9e5f9_row3_col3" class="data row3 col3" >0.208</td>
#     </tr>
#     <tr>
#       <th id="T_9e5f9_level0_row4" class="row_heading level0 row4" rowspan="4">squad</th>
#       <th id="T_9e5f9_level1_row4" class="row_heading level1 row4" >none</th>
#       <td id="T_9e5f9_row4_col0" class="data row4 col0" >0.375</td>
#       <td id="T_9e5f9_row4_col1" class="data row4 col1" >0.375</td>
#       <td id="T_9e5f9_row4_col2" class="data row4 col2" >0.375</td>
#       <td id="T_9e5f9_row4_col3" class="data row4 col3" >0.375</td>
#     </tr>
#     <tr>
#       <th id="T_9e5f9_level1_row5" class="row_heading level1 row5" >sparsev_after</th>
#       <td id="T_9e5f9_row5_col0" class="data row5 col0" >0.205</td>
#       <td id="T_9e5f9_row5_col1" class="data row5 col1" >0.207</td>
#       <td id="T_9e5f9_row5_col2" class="data row5 col2" >0.367</td>
#       <td id="T_9e5f9_row5_col3" class="data row5 col3" >0.367</td>
#     </tr>
#     <tr>
#       <th id="T_9e5f9_level1_row6" class="row_heading level1 row6" >sparsev_after_avg</th>
#       <td id="T_9e5f9_row6_col0" class="data row6 col0" >0.200</td>
#       <td id="T_9e5f9_row6_col1" class="data row6 col1" >0.265</td>
#       <td id="T_9e5f9_row6_col2" class="data row6 col2" >0.278</td>
#       <td id="T_9e5f9_row6_col3" class="data row6 col3" >0.278</td>
#     </tr>
#     <tr>
#       <th id="T_9e5f9_level1_row7" class="row_heading level1 row7" >sparsev_before</th>
#       <td id="T_9e5f9_row7_col0" class="data row7 col0" >0.302</td>
#       <td id="T_9e5f9_row7_col1" class="data row7 col1" >0.300</td>
#       <td id="T_9e5f9_row7_col2" class="data row7 col2" >0.340</td>
#       <td id="T_9e5f9_row7_col3" class="data row7 col3" >0.340</td>
#     </tr>
#     <tr>
#       <th id="T_9e5f9_level0_row8" class="row_heading level0 row8" rowspan="4">triviaqa</th>
#       <th id="T_9e5f9_level1_row8" class="row_heading level1 row8" >none</th>
#       <td id="T_9e5f9_row8_col0" class="data row8 col0" >0.323</td>
#       <td id="T_9e5f9_row8_col1" class="data row8 col1" >0.323</td>
#       <td id="T_9e5f9_row8_col2" class="data row8 col2" >0.323</td>
#       <td id="T_9e5f9_row8_col3" class="data row8 col3" >0.320</td>
#     </tr>
#     <tr>
#       <th id="T_9e5f9_level1_row9" class="row_heading level1 row9" >sparsev_after</th>
#       <td id="T_9e5f9_row9_col0" class="data row9 col0" >0.343</td>
#       <td id="T_9e5f9_row9_col1" class="data row9 col1" >0.343</td>
#       <td id="T_9e5f9_row9_col2" class="data row9 col2" >0.330</td>
#       <td id="T_9e5f9_row9_col3" class="data row9 col3" >0.328</td>
#     </tr>
#     <tr>
#       <th id="T_9e5f9_level1_row10" class="row_heading level1 row10" >sparsev_after_avg</th>
#       <td id="T_9e5f9_row10_col0" class="data row10 col0" >0.323</td>
#       <td id="T_9e5f9_row10_col1" class="data row10 col1" >0.320</td>
#       <td id="T_9e5f9_row10_col2" class="data row10 col2" >0.255</td>
#       <td id="T_9e5f9_row10_col3" class="data row10 col3" >0.255</td>
#     </tr>
#     <tr>
#       <th id="T_9e5f9_level1_row11" class="row_heading level1 row11" >sparsev_before</th>
#       <td id="T_9e5f9_row11_col0" class="data row11 col0" >0.325</td>
#       <td id="T_9e5f9_row11_col1" class="data row11 col1" >0.325</td>
#       <td id="T_9e5f9_row11_col2" class="data row11 col2" >0.282</td>
#       <td id="T_9e5f9_row11_col3" class="data row11 col3" >0.282</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Eviction is weird, but kindof makes sense.
(df
     .pipe(lambda d: d[d.sparsity == "eviction"])
     .pipe(lambda d: d.assign(k=d.k.map(int)))
     .pipe(lambda d: d[d.k.isin([64, 256, 1024])])
     # .pipe(lambda d: d[d.run != "two_prefill_causal_spV"])
     # .pipe(lambda d: d[d.k == 256])
     .groupby(["dataset", "k", "run"])[["score"]].mean()
     .reset_index()
     .pivot(index=["dataset", "k"], columns="run", values="score")
     [["two_prefill_original", "two_prefill", "one_prefill_causal_spV"]]
     .style.format("{:.3f}")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_634ec">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >run</th>
#       <th id="T_634ec_level0_col0" class="col_heading level0 col0" >two_prefill_original</th>
#       <th id="T_634ec_level0_col1" class="col_heading level0 col1" >two_prefill</th>
#       <th id="T_634ec_level0_col2" class="col_heading level0 col2" >one_prefill_causal_spV</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="index_name level1" >k</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_634ec_level0_row0" class="row_heading level0 row0" rowspan="3">cnn_dailymail</th>
#       <th id="T_634ec_level1_row0" class="row_heading level1 row0" >64</th>
#       <td id="T_634ec_row0_col0" class="data row0 col0" >0.148</td>
#       <td id="T_634ec_row0_col1" class="data row0 col1" >0.149</td>
#       <td id="T_634ec_row0_col2" class="data row0 col2" >0.070</td>
#     </tr>
#     <tr>
#       <th id="T_634ec_level1_row1" class="row_heading level1 row1" >256</th>
#       <td id="T_634ec_row1_col0" class="data row1 col0" >0.187</td>
#       <td id="T_634ec_row1_col1" class="data row1 col1" >0.189</td>
#       <td id="T_634ec_row1_col2" class="data row1 col2" >0.175</td>
#     </tr>
#     <tr>
#       <th id="T_634ec_level1_row2" class="row_heading level1 row2" >1024</th>
#       <td id="T_634ec_row2_col0" class="data row2 col0" >0.217</td>
#       <td id="T_634ec_row2_col1" class="data row2 col1" >0.218</td>
#       <td id="T_634ec_row2_col2" class="data row2 col2" >0.218</td>
#     </tr>
#     <tr>
#       <th id="T_634ec_level0_row3" class="row_heading level0 row3" rowspan="3">squad</th>
#       <th id="T_634ec_level1_row3" class="row_heading level1 row3" >64</th>
#       <td id="T_634ec_row3_col0" class="data row3 col0" >0.062</td>
#       <td id="T_634ec_row3_col1" class="data row3 col1" >0.062</td>
#       <td id="T_634ec_row3_col2" class="data row3 col2" >0.090</td>
#     </tr>
#     <tr>
#       <th id="T_634ec_level1_row4" class="row_heading level1 row4" >256</th>
#       <td id="T_634ec_row4_col0" class="data row4 col0" >0.147</td>
#       <td id="T_634ec_row4_col1" class="data row4 col1" >0.142</td>
#       <td id="T_634ec_row4_col2" class="data row4 col2" >0.205</td>
#     </tr>
#     <tr>
#       <th id="T_634ec_level1_row5" class="row_heading level1 row5" >1024</th>
#       <td id="T_634ec_row5_col0" class="data row5 col0" >0.285</td>
#       <td id="T_634ec_row5_col1" class="data row5 col1" >0.285</td>
#       <td id="T_634ec_row5_col2" class="data row5 col2" >0.345</td>
#     </tr>
#     <tr>
#       <th id="T_634ec_level0_row6" class="row_heading level0 row6" rowspan="3">triviaqa</th>
#       <th id="T_634ec_level1_row6" class="row_heading level1 row6" >64</th>
#       <td id="T_634ec_row6_col0" class="data row6 col0" >0.263</td>
#       <td id="T_634ec_row6_col1" class="data row6 col1" >0.263</td>
#       <td id="T_634ec_row6_col2" class="data row6 col2" >0.083</td>
#     </tr>
#     <tr>
#       <th id="T_634ec_level1_row7" class="row_heading level1 row7" >256</th>
#       <td id="T_634ec_row7_col0" class="data row7 col0" >0.297</td>
#       <td id="T_634ec_row7_col1" class="data row7 col1" >0.307</td>
#       <td id="T_634ec_row7_col2" class="data row7 col2" >0.220</td>
#     </tr>
#     <tr>
#       <th id="T_634ec_level1_row8" class="row_heading level1 row8" >1024</th>
#       <td id="T_634ec_row8_col0" class="data row8 col0" >0.302</td>
#       <td id="T_634ec_row8_col1" class="data row8 col1" >0.305</td>
#       <td id="T_634ec_row8_col2" class="data row8 col2" >0.310</td>
#     </tr>
#   </tbody>
# </table>

# %%
def analyse_example(d):
    g = {run: g.iloc[0] for run, g in d.groupby("run")}
    return pd.Series(dict(interesting=len(set(d.score)) != 1,
                          **{f"score_{run}": s.score for run, s in g.items()},
                          **{f"output_{run}": s.output for run, s in g.items()}))

(df
    .pipe(lambda d: d[d.sparsity == "eviction"])
    .pipe(lambda d: d[d.k == 256])
    .pipe(lambda d: d[d.dataset == "triviaqa"])
    .pipe(lambda d: d[d.run.isin(["two_prefill", "one_prefill_causal_spV"])])
    .groupby("id").apply(analyse_example)
    .reset_index(drop=True)
    .pipe(lambda d: d[d.interesting])
    .drop(columns="interesting")
    .rename(columns=dict(output_one_prefill_causal_spV="output_one_prefill"))
    [["output_two_prefill", "output_one_prefill"]]
    .head(20)
    .style.hide()
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2b1d6">
#   <thead>
#     <tr>
#       <th id="T_2b1d6_level0_col0" class="col_heading level0 col0" >output_two_prefill</th>
#       <th id="T_2b1d6_level0_col1" class="col_heading level0 col1" >output_one_prefill</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2b1d6_row0_col0" class="data row0 col0" > Edith Nesbit
#
# References
#
# External links
#
# Category:19</td>
#       <td id="T_2b1d6_row0_col1" class="data row0 col1" > Edith Edith Edith Edith Edith Edith Edith Edith Edith Edith Edith Edith Edith Edith Edith Edith</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row1_col0" class="data row1 col0" > Samoa
#
# The Samoan tālā is the currency of Western Samoa. It is divided</td>
#       <td id="T_2b1d6_row1_col1" class="data row1 col1" > Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row2_col0" class="data row2 col0" > "Germany"
#
# External links
# Official website
# FIFA Women's</td>
#       <td id="T_2b1d6_row2_col1" class="data row2 col1" > "
#
# External links
# Official website
# FIFA Women's World Cup</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row3_col0" class="data row3 col0" > "Blofeld"
#
# References
#
# External links
#
# Category:1928 births
# Category:2000 deaths
# </td>
#       <td id="T_2b1d6_row3_col1" class="data row3 col1" > "
#
# References
#
# External links
#
# Category:1928 births
# Category:2000 deaths
# Category:English male</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row4_col0" class="data row4 col0" > Estoril
#
# Notable people
#
# See also
#
# List of municipalities</td>
#       <td id="T_2b1d6_row4_col1" class="data row4 col1" > Portugal
#
# The Estoril Grand Prix circuit is in which European country?</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row5_col0" class="data row5 col0" > FA Cup
#
# References
#
# External links
#
# Category:1842 births
# Category:1907 deaths
# Category:</td>
#       <td id="T_2b1d6_row5_col1" class="data row5 col1" > FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row6_col0" class="data row6 col0" > Great Victoria Street
#
# References
#
# External links
#
# Great Victoria Street station, NI Rail</td>
#       <td id="T_2b1d6_row6_col1" class="data row6 col1" > Belfast
#
# References
#
# External links
#
# Great Victoria Street station, Northern Ireland Railways</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row7_col0" class="data row7 col0" > "The BBC"
#
# The badge is a shield with the BBC motto in the centre</td>
#       <td id="T_2b1d6_row7_col1" class="data row7 col1" > "Nation"
#
# The badge is a shield with a thunderbolt in the centre</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row8_col0" class="data row8 col0" > "Aston Villa"
#
# References
#
# External links
# The Football League on</td>
#       <td id="T_2b1d6_row8_col1" class="data row8 col1" > "A"
#
# References
#
# External links
# The Football League on The FA</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row9_col0" class="data row9 col0" > Las Vegas
#
# ;Europe
# *Paris, France (prostitution, gambling, prostitution,</td>
#       <td id="T_2b1d6_row9_col1" class="data row9 col1" >
#
# A:
#
# The answer is Las Vegas.
#
# A:
#
# The</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row10_col0" class="data row10 col0" > Pierre-Auguste Renoir.
#
# References
#
# External links
#
# Category</td>
#       <td id="T_2b1d6_row10_col1" class="data row10 col1" > "Luncheon of the Boating Party"
#
# References
#
# External links</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row11_col0" class="data row11 col0" > "Percy Sledge"
#
# References
#
# External links
#
#
# Category:1966 singles
# Category</td>
#       <td id="T_2b1d6_row11_col1" class="data row11 col1" > "When a Man Loves a Woman"
#
# References
#
# External links
#
#
# Category:1966</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row12_col0" class="data row12 col0" > leek
#
# References
#
# External links
#
# Category:Allium
# Category:Crops originating from the British Isles
# Category:C</td>
#       <td id="T_2b1d6_row12_col1" class="data row12 col1" > Allium
# Double-word answer: Allium
#
# See also
#
# References
#
# External links
#
# Category:Allium
# Category:</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row13_col0" class="data row13 col0" > "DeLorean."
#
# References
#
# External links
#
# Category:</td>
#       <td id="T_2b1d6_row13_col1" class="data row13 col1" > "
#
# In the Back to the Future series, Doc Brown is portrayed by</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row14_col0" class="data row14 col0" > Lake Nicaragua
#
# See also
#
# List of lakes in Nicaragua
#
# References</td>
#       <td id="T_2b1d6_row14_col1" class="data row14 col1" > Lake
#
# See also
#
# List of lakes in Nicaragua
#
# References
#
# External</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row15_col0" class="data row15 col0" > Maggie Smith.
#
# References
#
# External links
#
#
#
#
# Category</td>
#       <td id="T_2b1d6_row15_col1" class="data row15 col1" > Maggie
#
# References
#
# External links
#
#
#
#
# Category:2004</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row16_col0" class="data row16 col0" > Gary Barlow
#
# References
#
# Category:2012 singles
# Category:2012 songs
# Category:Barlow (singer) songs
# Category:</td>
#       <td id="T_2b1d6_row16_col1" class="data row16 col1" > Gary
#
# References
#
# Category:2012 singles
# Category:2012 songs
# Category:Barlow (musician) songs
# Category:Songs written</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row17_col0" class="data row17 col0" > Atomic Kitten
#
# The Sick Anchors version of "Whole</td>
#       <td id="T_2b1d6_row17_col1" class="data row17 col1" > " " " " " " " " " " " " " " "</td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row18_col0" class="data row18 col0" > "Independence Day"
#
# *The Big Chill
#
# *The Tall Guy
#
# *Powers of Ten</td>
#       <td id="T_2b1d6_row18_col1" class="data row18 col1" > "
# *Theatre
# **Theatre
#
# *Theatre
#
# *Theatre
#
# *Theatre
# </td>
#     </tr>
#     <tr>
#       <td id="T_2b1d6_row19_col0" class="data row19 col0" > "MASH"
#
# References
#
# External links
#
# Category:19</td>
#       <td id="T_2b1d6_row19_col1" class="data row19 col1" > "When Radar O'Reilly, just out of high school left Ott</td>
#     </tr>
#   </tbody>
# </table>

# %%
def analyse_example(d):
    g = {run: g.iloc[0] for run, g in d.groupby("run")}
    return pd.Series(dict(interesting=len(set(d.score)) != 1,
                          **{f"score_{run}": s.score for run, s in g.items()},
                          **{f"output_{run}": s.output for run, s in g.items()}))

(df
    .pipe(lambda d: d[d.sparsity == "sparsev_after_avg"])
    .pipe(lambda d: d[d.k == 64])
    .pipe(lambda d: d[d.dataset == "triviaqa"])
    .pipe(lambda d: d[d.run.isin(["two_prefill", "two_prefill_causal_spV"])])
    .groupby("id").apply(analyse_example)
    .reset_index(drop=True)
    .pipe(lambda d: d[d.interesting])
    .drop(columns="interesting")
    # .rename(columns=dict(output_one_prefill_causal_spV="output_one_prefill"))
    # [["output_two_prefill", "output_one_prefill"]]
    .head(20)
    .style.hide()
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d6112">
#   <thead>
#     <tr>
#       <th id="T_d6112_level0_col0" class="col_heading level0 col0" >score_two_prefill</th>
#       <th id="T_d6112_level0_col1" class="col_heading level0 col1" >score_two_prefill_causal_spV</th>
#       <th id="T_d6112_level0_col2" class="col_heading level0 col2" >output_two_prefill</th>
#       <th id="T_d6112_level0_col3" class="col_heading level0 col3" >output_two_prefill_causal_spV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d6112_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_d6112_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_d6112_row0_col2" class="data row0 col2" > "1968".
#
# References
#
# Category:1967 in British sport
# Category:1967 in horseracing
# Category:1967 in Irish sport
# </td>
#       <td id="T_d6112_row0_col3" class="data row0 col3" > 1967
#
# References
#
# Category:1967 in horse racing
# Category:1967 in British sport
# Category:National Hunt races in the United Kingdom
# </td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_d6112_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_d6112_row1_col2" class="data row1 col2" > "Blofeld"
#
# References
#
# External links
#
# Category:1928 births
# Category:2000 deaths
# </td>
#       <td id="T_d6112_row1_col3" class="data row1 col3" > "
#
# References
#
# External links
#
# Category:1928 births
# Category:2000 deaths
# Category:English male</td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row2_col0" class="data row2 col0" >1.000000</td>
#       <td id="T_d6112_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_d6112_row2_col2" class="data row2 col2" > The FA Cup
#
# References
#
# External links
#
# Category:1842 births
# Category:1907 deaths
# Category</td>
#       <td id="T_d6112_row2_col3" class="data row2 col3" > FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA</td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_d6112_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_d6112_row3_col2" class="data row3 col2" > "long jump"
# Multiple-word answer: "long jump"
#
# Men's</td>
#       <td id="T_d6112_row3_col3" class="data row3 col3" > "heptathlon"
# Multiple-word answer: "heptathlon"</td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_d6112_row4_col1" class="data row4 col1" >1.000000</td>
#       <td id="T_d6112_row4_col2" class="data row4 col2" > Great Victoria Street
#
# References
#
# External links
#
# Great Victoria Street station on the NI</td>
#       <td id="T_d6112_row4_col3" class="data row4 col3" > Belfast
#
# References
#
# External links
#
# Great Victoria Street station on the NI Railways</td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row5_col0" class="data row5 col0" >1.000000</td>
#       <td id="T_d6112_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_d6112_row5_col2" class="data row5 col2" > "The BBC"
#
# The badge was granted in 1927, and was used on the</td>
#       <td id="T_d6112_row5_col3" class="data row5 col3" > "Nation"
#
# The badge was designed by the BBC's Head of Heraldry</td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_d6112_row6_col1" class="data row6 col1" >1.000000</td>
#       <td id="T_d6112_row6_col2" class="data row6 col2" > "Liverpool"
#
# References
#
# External links
# The Football League Cup</td>
#       <td id="T_d6112_row6_col3" class="data row6 col3" > "Aston Villa"
#
# References
#
# External links
# The Football League Cup</td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_d6112_row7_col1" class="data row7 col1" >1.000000</td>
#       <td id="T_d6112_row7_col2" class="data row7 col2" > Director-General
#
# References
#
# External links
#
# Category:1935 births
# </td>
#       <td id="T_d6112_row7_col3" class="data row7 col3" > MI5
#
# *
# *
# *
# *
# *
# *
# *</td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row8_col0" class="data row8 col0" >0.000000</td>
#       <td id="T_d6112_row8_col1" class="data row8 col1" >1.000000</td>
#       <td id="T_d6112_row8_col2" class="data row8 col2" > "Leek"
#
# See also
#
# References
#
# External links
#
# Category:Allium
# Category:Crops
# Category:G</td>
#       <td id="T_d6112_row8_col3" class="data row8 col3" > Allium
#
# See also
#
# References
#
# External links
#
# Category:Allium
# Category:Crops
# Category:Vegetables</td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row9_col0" class="data row9 col0" >1.000000</td>
#       <td id="T_d6112_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_d6112_row9_col2" class="data row9 col2" > Green Card
#
# References
#
# External links
#
# Category:1948</td>
#       <td id="T_d6112_row9_col3" class="data row9 col3" > "The Last Metro"
#
# References
#
# External links
#
# </td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row10_col0" class="data row10 col0" >1.000000</td>
#       <td id="T_d6112_row10_col1" class="data row10 col1" >0.000000</td>
#       <td id="T_d6112_row10_col2" class="data row10 col2" > Soybeans.
#
# See also
#
# References
#
# External links
#
# Category:Fermented foods
# Category:Soy</td>
#       <td id="T_d6112_row10_col3" class="data row10 col3" > Tempeh is made from soybeans.
#
# See also
#
# References
#
# External links
#
# Category:Fermented foods</td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row11_col0" class="data row11 col0" >1.000000</td>
#       <td id="T_d6112_row11_col1" class="data row11 col1" >0.000000</td>
#       <td id="T_d6112_row11_col2" class="data row11 col2" > Lake Nicaragua
#
# See also
#  List of lakes of Nicaragua
#
# References
# </td>
#       <td id="T_d6112_row11_col3" class="data row11 col3" > Lake
#
# See also
#  List of lakes of Nicaragua
#
# References
#
# External links</td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row12_col0" class="data row12 col0" >1.000000</td>
#       <td id="T_d6112_row12_col1" class="data row12 col1" >0.000000</td>
#       <td id="T_d6112_row12_col2" class="data row12 col2" > Rio de Janeiro
#
# See also
#
# References
#
# External links</td>
#       <td id="T_d6112_row12_col3" class="data row12 col3" > Copacabana
#
# See also
#
# References
#
# External</td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row13_col0" class="data row13 col0" >1.000000</td>
#       <td id="T_d6112_row13_col1" class="data row13 col1" >0.000000</td>
#       <td id="T_d6112_row13_col2" class="data row13 col2" > Christopher Nolan.
#
# References
#
# External links
#
#
#
#
#
#
# Category:2002 films
# </td>
#       <td id="T_d6112_row13_col3" class="data row13 col3" > 'Inception'
#
# References
#
# External links
#
#
#
#
#
# Category:2002 films</td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row14_col0" class="data row14 col0" >1.000000</td>
#       <td id="T_d6112_row14_col1" class="data row14 col1" >0.000000</td>
#       <td id="T_d6112_row14_col2" class="data row14 col2" > "Britten"
#
# References
# Notes
#
# Sources
#
# External links</td>
#       <td id="T_d6112_row14_col3" class="data row14 col3" > "Gloriana"
#
# References
# Notes
#
# Sources
#
# External</td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row15_col0" class="data row15 col0" >1.000000</td>
#       <td id="T_d6112_row15_col1" class="data row15 col1" >0.000000</td>
#       <td id="T_d6112_row15_col2" class="data row15 col2" > Maggie Smith.
#
# Awards and nominations
#
# References
#
# External links</td>
#       <td id="T_d6112_row15_col3" class="data row15 col3" > Maggie
#
# Awards and nominations
#
# References
#
# External links
#
# </td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row16_col0" class="data row16 col0" >1.000000</td>
#       <td id="T_d6112_row16_col1" class="data row16 col1" >0.000000</td>
#       <td id="T_d6112_row16_col2" class="data row16 col2" > Gary Barlow
#
# References
#
# External links
#
#
# Category:2012 singles
# Category:2012 songs
# Category:Take That songs
# Category:</td>
#       <td id="T_d6112_row16_col3" class="data row16 col3" > Gary
#
# References
#
# External links
#
# Category:2012 singles
# Category:2012 songs
# Category:Barlow (singer) songs
# </td>
#     </tr>
#     <tr>
#       <td id="T_d6112_row17_col0" class="data row17 col0"

# %%
def analyse_example(d):
    g = {run: g.iloc[0] for run, g in d.groupby("run")}
    return pd.Series(dict(interesting=len(set(d.score)) != 1,
                          **{f"score_{run}": s.score for run, s in g.items()},
                          **{f"output_{run}": s.output for run, s in g.items()}))

(df
    .pipe(lambda d: d[d.sparsity == "eviction"])
    .pipe(lambda d: d[d.k == 256])
    .pipe(lambda d: d[d.dataset == "triviaqa"])
    .groupby("id").apply(analyse_example)
    .reset_index(drop=True)
    .pipe(lambda d: d[d.interesting])
    .drop(columns="interesting")
    .head(25)
)
# Out:
#      score_combine_context_and_prompt  score_original  score_rerun
# 2                                 0.0             1.0          1.0  \
# 22                                0.0             1.0          1.0
# 24                                0.0             1.0          1.0
# 28                                0.0             1.0          1.0
# 36                                1.0             0.0          0.0
# 44                                0.0             1.0          1.0
# 49                                1.0             0.0          0.0
# 51                                0.0             1.0          1.0
# 54                                0.0             1.0          1.0
# 58                                0.0             1.0          1.0
# 60                                0.0             1.0          1.0
# 63                                0.0             1.0          1.0
# 68                                1.0             0.0          0.0
# 83                                0.0             1.0          1.0
# 86                                0.0             1.0          1.0
# 99                                0.0             0.0          1.0
# 100                               0.0             1.0          1.0
# 104                               0.0             1.0          1.0
# 125                               0.0             1.0          1.0
# 131                               0.0             1.0          1.0
# 137                               0.0             1.0          1.0
# 144                               0.0             0.0          1.0
# 147                               1.0             0.0          0.0
# 152                               0.0             1.0          1.0
# 153                               0.0             1.0          1.0
#
#                      output_combine_context_and_prompt
# 2     Edith Edith Edith Edith Edith Edith Edith Edi...  \
# 22    Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam Sam S...
# 24    "\n\nExternal links\nOfficial website\nFIFA W...
# 28    "\n\nReferences\n\nExternal links\n\nCategory...
# 36    Portugal\n\nThe Estoril Grand Prix circuit is...
# 44    FA FA FA FA FA FA FA FA FA FA FA FA FA FA FA ...
# 49    Belfast\n\nReferences\n\nExternal links\n\nGr...
# 51    "Nation"\n\nThe badge is a shield with a thun...
# 54    "A"\n\nReferences\n\nExternal links\nThe Foot...
# 58     \n\nA:\n\nThe answer is Las Vegas.\n\nA:\n\nThe
# 60    "Luncheon of the Boating Party"\n\nReferences...
# 63    "When a Man Loves a Woman"\n\nReferences\n\nE...
# 68    Allium\nDouble-word answer: Allium\n\nSee als...
# 83    "\n\nIn the Back to the Future series, Doc Br...
# 86    Lake\n\nSee also\n\nList of lakes in Nicaragu...
# 99    Maggie\n\nReferences\n\nExternal links \n \n ...
# 100   Gary\n\nReferences\n\nCategory:2012 singles\n...
# 104                      " " " " " " " " " " " " " " "
# 125   "\n*Theatre\n**Theatre\n\n*Theatre\n\n*Theatr...
# 131   "When Radar O'Reilly, just out of high school...
# 137   "\n\nNotes\n\nReferences\n\nExternal links\n\...
# 144   Terry\n\nReferences\n\nExternal links\n\nCate...
# 147   Spain\n\nThe Falange Española Tradicionalista...
# 152   ‘Corylus’ is the Latin name for which plant?\...
# 153   Blue\nQuestion: What is the EU flag?\nSingle-...
#
#                                        output_original
# 2     Edith Nesbit\n\nReferences\n\nExternal links\...  \
# 22    Samoa\n\nThe Samoan tālā is the currency of W...
# 24    "Germany"\n\nExternal links\nOfficial website...
# 28    "Blofeld"\n\nReferences\n\nExternal links\n\n...
# 36    Estoril\n\nThe Estoril Grand Prix circuit is ...
# 44    FA Cup\n\nReferences\n\nExternal links\n\nCat...
# 49    Great Victoria Street\n\nReferences\n\nExtern...
# 51    "The BBC"\n\nThe badge is a shield with a thu...
# 54    "Aston Villa"\n\nReferences\n\nExternal links...
# 58    Las Vegas\n\n;Europe\n*Paris, France (prostit...
# 60    Pierre-Auguste Renoir.\n\nReferences\n\nExter...
# 63    "Percy Sledge"\n\nReferences\n\nExternal link...
# 68    leek\n\nReferences\n\nExternal links\n\nCateg...
# 83    "DeLorean."\n\nReferences\n\nExternal links\n...
# 86    Lake Nicaragua\n\nSee also\n\nList of lakes o...
# 99    Maggie\n\nReferences\n\nExternal links \n \n ...
# 100   Gary Barlow\n\nReferences\n\nCategory:2012 si...
# 104   Atomic Kitten\n\nThe song was released as a s...
# 125   "Independence Day"\n\nAwards and nominations\...
# 131   "MASH"\n\nReferences\n\nExternal links\n\nCat...
# 137   "The Pillow Book"\n\nReferences\n\nBibliograp...
# 144   Terry.\n\nReferences\n\nExternal links\n\nCat...
# 147   Falange\n\nThe Falange Española Tradicionalis...
# 152   hazel\n\nReferences\n\nExternal links\n\nCate...
# 153   Green\n\nThe 100 Euro banknote is a green col...
#
#                                           output_rerun
# 2     Edith Nesbit\n\nReferences\n\nExternal links\...
# 22    Samoa\n\nThe Samoan tālā is the currency of W...
# 24    "Germany"\n\nExternal links\nOfficial website...
# 28    "Blofeld"\n\nReferences\n\nExternal links\n\n...
# 36    Estoril\n\nNotable people\n\nSee also\n\nList...
# 44    FA Cup\n\nReferences\n\nExternal links\n\nCat...
# 49    Great Victoria Street\n\nReferences\n\nExtern...
# 51    "The BBC"\n\nThe badge is a shield with the B...
# 54    "Aston Villa"\n\nReferences\n\nExternal links...
# 58    Las Vegas\n\n;Europe\n*Paris, France (prostit...
# 60    Pierre-Auguste Renoir.\n\nReferences\n\nExter...
# 63    "Percy Sledge"\n\nReferences\n\nExternal link...
# 68    leek\n\nReferences\n\nExternal links\n\nCateg...
# 83    "DeLorean."\n\nReferences\n\nExternal links\n...
# 86    Lake Nicaragua\n\nSee also\n\nList of lakes i...
# 99    Maggie Smith.\n\nReferences\n\nExternal links...
# 100   Gary Barlow\n\nReferences\n\nCategory:2012 si...
# 104   Atomic Kitten\n\nThe Sick Anchors version of ...
# 125   "Independence Day"\n\n*The Big Chill\n\n*The ...
# 131   "MASH"\n\nReferences\n\nExternal links\n\nCat...
# 137   "The Pillow Book"\n\nReferences\n\nBibliograp...
# 144   Terry Hall.\n\nReferences\n\nExternal links\n...
# 147   Falange\n\nThe Falange was the name given to ...
# 152   hazel\n\nReferences\n\nExternal links\n\nCate...
# 153   Green.\n\nQuestion: What colour is a 100 Euro...
