# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Average left-over tokens (Wiki context)

# %% [markdown]
# These runs use examples from TriviaQA with **Wikipedia** contexts of length 4000-8000 characters.

# %% [markdown]
# ## Results

# %%
df = pd.read_json("./results/triviaqa_add_avg_wiki.jsonl", lines=True)

# %%
df
# Out:
#           model     acc    k  add_avg  open_book    _duration
# 0    pythia-70m  0.0025    8    False       True    59.894273
# 1    pythia-70m  0.0100    8     True       True    52.081464
# 2    pythia-70m  0.0050   16    False       True    52.137871
# 3    pythia-70m  0.0050   16     True       True    53.982744
# 4    pythia-70m  0.0050   32    False       True    53.625786
# 5    pythia-70m  0.0125   32     True       True    57.015582
# 6    pythia-70m  0.0075   64    False       True    52.219161
# 7    pythia-70m  0.0075   64     True       True    57.874753
# 8    pythia-70m  0.0050  128    False       True    50.074396
# 9    pythia-70m  0.0025  128     True       True    54.791075
# 10  pythia-160m  0.0275    8    False       True   160.678055
# 11  pythia-160m  0.0275    8     True       True   166.567397
# 12  pythia-160m  0.0425   16    False       True   134.350727
# 13  pythia-160m  0.0450   16     True       True   131.552164
# 14  pythia-160m  0.0550   32    False       True   139.557012
# 15  pythia-160m  0.0550   32     True       True   126.926918
# 16  pythia-160m  0.0600   64    False       True   131.893957
# 17  pythia-160m  0.0650   64     True       True   145.160182
# 18  pythia-160m  0.0650  128    False       True   137.337351
# 19  pythia-160m  0.0725  128     True       True   126.762504
# 20  pythia-410m  0.1500    8    False       True   350.576257
# 21  pythia-410m  0.1850    8     True       True   363.055545
# 22  pythia-410m  0.1875   16    False       True   330.187376
# 23  pythia-410m  0.2150   16     True       True   316.911974
# 24  pythia-410m  0.2200   32    False       True   326.482947
# 25  pythia-410m  0.2325   32     True       True   325.424772
# 26  pythia-410m  0.2325   64    False       True   305.702763
# 27  pythia-410m  0.2425   64     True       True   344.198694
# 28  pythia-410m  0.2375  128    False       True   316.637324
# 29  pythia-410m  0.2425  128     True       True   329.658182
# 30    pythia-1b  0.1775    8    False       True   731.432842
# 31    pythia-1b  0.2450    8     True       True   772.942518
# 32    pythia-1b  0.2325   16    False       True   713.016976
# 33    pythia-1b  0.2775   16     True       True   740.866389
# 34    pythia-1b  0.2950   32    False       True   687.875896
# 35    pythia-1b  0.3150   32     True       True   721.829766
# 36    pythia-1b  0.3425   64    False       True   711.164273
# 37    pythia-1b  0.3400   64     True       True   726.817868
# 38    pythia-1b  0.3700  128    False       True   720.441986
# 39    pythia-1b  0.3400  128     True       True   711.079237
# 40  pythia-1.4b  0.3225    8    False       True  1136.784869
# 41  pythia-1.4b  0.3550    8     True       True  1069.418889
# 42  pythia-1.4b  0.3625   16    False       True  1061.998015
# 43  pythia-1.4b  0.3825   16     True       True  1111.865448
# 44  pythia-1.4b  0.3675   32    False       True  1125.775222
# 45  pythia-1.4b  0.4075   32     True       True  1078.806885
# 46  pythia-1.4b  0.3925   64    False       True  1082.900709
# 47  pythia-1.4b  0.4150   64     True       True  1122.568369
# 48  pythia-1.4b  0.4050  128    False       True  1081.204224
# 49  pythia-1.4b  0.4175  128     True       True  1072.864331
# 50  pythia-2.8b  0.3525    8    False       True  1873.427581
# 51  pythia-2.8b  0.4050    8     True       True  1909.988524
# 52  pythia-2.8b  0.3575   16    False       True  1833.204177
# 53  pythia-2.8b  0.4525   16     True       True  1853.352290
# 54  pythia-2.8b  0.3925   32    False       True  1812.898799
# 55  pythia-2.8b  0.4525   32     True       True  1871.045022
# 56  pythia-2.8b  0.4350   64    False       True  1835.689866
# 57  pythia-2.8b  0.4650   64     True       True  1877.635194
# 58  pythia-2.8b  0.4575  128    False       True  1858.780940
# 59  pythia-2.8b  0.4775  128     True       True  1885.318993

# %%
# Filter out the smaller models
models_to_plot = ["pythia-410m", "pythia-1b", "pythia-1.4b", "pythia-2.8b"]
df = df.loc[df["model"].isin(models_to_plot)]

# %%
df_b = pd.read_json("./results/triviaqa_baseline_wiki.jsonl", lines=True)
df_b = df_b.loc[df_b["model"].isin(models_to_plot)]

# %%
model_grouped = df.groupby("model", sort=False)

# %%
fig, axes = plt.subplots()
linestyles = [":", "-"]
models = []
for i, (model, group) in enumerate(model_grouped):
    models.append(model)
    col = f"C{i}"
    
    # Plot dense baseline
    y = df_b.loc[(df_b["model"] == model) & (df_b['open_book'] == True), "acc"].values[0]
    plt.axhline(y = y, color = col, linestyle="--")
    
    avg_grouped = group.groupby("add_avg")
    for (use_avg, group), linestyle in zip(avg_grouped, linestyles):
        axes.plot(group["k"], group["acc"], label=f"{model}, use_avg={use_avg}", color=col, linestyle=linestyle)
lines = axes.get_lines()[2::3]

# Dummy lines
dummy_lines = []
for linestyle in linestyles:
    dummy_lines.append(axes.plot([],[], c="black", linestyle=linestyle)[0])
# Add baseline line
dummy_lines.append(axes.plot([],[], c="black", linestyle="--")[0])

legend1 = axes.legend(lines, models, loc="lower right")
legend2 = axes.legend(dummy_lines, ["use_avg = False", "use_avg = True", "Baseline"], loc="lower center")
axes.add_artist(legend1)
plt.xlabel("k (decreasing sparsity)")
plt.ylabel("Accuracy")
plt.title("TriviaQA-2k (wiki) accuracy")
plt.show()
