# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Use V-magnitudes

# %% [markdown]
# These runs use examples from TriviaQA with **Wikipedia** contexts of length 4000-8000 characters.

# %% [markdown]
# ## Results

# %%
df = pd.read_json("./results/triviaqa_wiki_use_v_mag.jsonl", lines=True)

# %%
df
# Out:
#           model     acc    k  use_v_mag  add_avg  open_book    _duration
# 0    pythia-70m  0.0025    8      False    False       True    64.064362
# 1    pythia-70m  0.0025    8       True    False       True    55.489895
# 2    pythia-70m  0.0050   16      False    False       True    55.984776
# 3    pythia-70m  0.0050   16       True    False       True    54.856807
# 4    pythia-70m  0.0050   32      False    False       True    56.609716
# 5    pythia-70m  0.0050   32       True    False       True    53.436790
# 6    pythia-70m  0.0075   64      False    False       True    56.361040
# 7    pythia-70m  0.0050   64       True    False       True    56.181857
# 8    pythia-70m  0.0050  128      False    False       True    52.216268
# 9    pythia-70m  0.0050  128       True    False       True    57.826051
# 10  pythia-160m  0.0275    8      False    False       True   165.344236
# 11  pythia-160m  0.0300    8       True    False       True   141.294143
# 12  pythia-160m  0.0425   16      False    False       True   140.624937
# 13  pythia-160m  0.0400   16       True    False       True   133.609434
# 14  pythia-160m  0.0550   32      False    False       True   160.634204
# 15  pythia-160m  0.0500   32       True    False       True   147.124594
# 16  pythia-160m  0.0600   64      False    False       True   131.567878
# 17  pythia-160m  0.0600   64       True    False       True   156.363993
# 18  pythia-160m  0.0650  128      False    False       True   133.716494
# 19  pythia-160m  0.0625  128       True    False       True   132.271417
# 20  pythia-410m  0.1500    8      False    False       True   348.267152
# 21  pythia-410m  0.1550    8       True    False       True   343.238363
# 22  pythia-410m  0.1875   16      False    False       True   337.895121
# 23  pythia-410m  0.1850   16       True    False       True   340.978795
# 24  pythia-410m  0.2200   32      False    False       True   332.137703
# 25  pythia-410m  0.2150   32       True    False       True   333.416763
# 26  pythia-410m  0.2325   64      False    False       True   364.075252
# 27  pythia-410m  0.2250   64       True    False       True   323.143087
# 28  pythia-410m  0.2375  128      False    False       True   335.144867
# 29  pythia-410m  0.2375  128       True    False       True   328.532118
# 30    pythia-1b  0.1775    8      False    False       True   728.991349
# 31    pythia-1b  0.1775    8       True    False       True   741.404923
# 32    pythia-1b  0.2325   16      False    False       True   724.266001
# 33    pythia-1b  0.2350   16       True    False       True   753.962933
# 34    pythia-1b  0.2950   32      False    False       True   706.087564
# 35    pythia-1b  0.3025   32       True    False       True   713.360047
# 36    pythia-1b  0.3425   64      False    False       True   717.713738
# 37    pythia-1b  0.3400   64       True    False       True   728.908447
# 38    pythia-1b  0.3700  128      False    False       True   716.663419
# 39    pythia-1b  0.3750  128       True    False       True   719.822679
# 40  pythia-1.4b  0.3225    8      False    False       True  1082.829418
# 41  pythia-1.4b  0.3225    8       True    False       True  1091.512700
# 42  pythia-1.4b  0.3625   16      False    False       True  1108.219378
# 43  pythia-1.4b  0.3600   16       True    False       True  1104.248873
# 44  pythia-1.4b  0.3675   32      False    False       True  1106.009389
# 45  pythia-1.4b  0.3625   32       True    False       True  1080.937621
# 46  pythia-1.4b  0.3925   64      False    False       True  1106.805626
# 47  pythia-1.4b  0.4025   64       True    False       True  1103.683131
# 48  pythia-1.4b  0.4050  128      False    False       True  1153.459159
# 49  pythia-1.4b  0.4000  128       True    False       True  1088.886938
# 50  pythia-2.8b  0.3525    8      False    False       True  1890.746914
# 51  pythia-2.8b  0.3650    8       True    False       True  1856.740709
# 52  pythia-2.8b  0.3575   16      False    False       True  1857.157954
# 53  pythia-2.8b  0.3825   16       True    False       True  1859.117126
# 54  pythia-2.8b  0.3925   32      False    False       True  1859.964600
# 55  pythia-2.8b  0.3950   32       True    False       True  1818.485029
# 56  pythia-2.8b  0.4350   64      False    False       True  1853.517632
# 57  pythia-2.8b  0.4275   64       True    False       True  1879.710212
# 58  pythia-2.8b  0.4575  128      False    False       True  1893.325661
# 59  pythia-2.8b  0.4525  128       True    False       True  1862.259897

# %%
# Filter out the smaller models
models_to_plot = ["pythia-410m", "pythia-1b", "pythia-1.4b", "pythia-2.8b"]
df = df.loc[df["model"].isin(models_to_plot)]

# %%
df_b = pd.read_json("./results/triviaqa_wiki_baseline.jsonl", lines=True)
df_b = df_b.loc[df_b["model"].isin(models_to_plot)]

# %%
model_grouped = df.groupby("model", sort=False)

# %%
fig, axes = plt.subplots()
linestyles = {False: ":", True: "-"}
models = []
for i, (model, group) in enumerate(model_grouped):
    models.append(model)
    col = f"C{i}"
    
    # Plot dense baseline
    y = df_b.loc[(df_b["model"] == model) & (df_b['open_book'] == True), "acc"].values[0]
    plt.axhline(y = y, color = col, linestyle="--")
    
    v_mag_grouped = group.groupby("use_v_mag")
    for use_v_mag, group in v_mag_grouped:
        axes.plot(group["k"], group["acc"], label=f"{model}, use_v_mag={use_v_mag}", color=col, linestyle=linestyles[use_v_mag])
lines = axes.get_lines()[2::3]

# Dummy lines
dummy_lines = []
dummy_labels = []
for k, v in linestyles.items():
    dummy_lines.append(axes.plot([],[], c="black", linestyle=v)[0])
    dummy_labels.append(f"use_v_mag={k}")
# Add baseline line
dummy_lines.append(axes.plot([],[], c="black", linestyle="--")[0])
dummy_labels.append("Baseline")

legend1 = axes.legend(lines, models, loc="lower right")
legend2 = axes.legend(dummy_lines, dummy_labels, loc="lower center")
axes.add_artist(legend1)
plt.xlabel("k (decreasing sparsity)")
plt.ylabel("Accuracy")
plt.title("TriviaQA-2k (wiki) accuracy")
plt.show()
